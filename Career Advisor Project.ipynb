# %% [markdown]
# # **AI Career Advisor**: A Predictive Model for Career Path Selection.

# %% [markdown]
# ## **Description**
#
# This project will leverage machine learning to guide individuals in discovering career paths aligned with their personalities, interests, and work preferences. By analyzing a range of factors, the model aims to provide tailored career recommendations for individuals just starting out, and professionals seeking a career transition.

# %% [markdown]
# ## **Initial Road Map**
#
# #### **Define the Problem:**
#
# The aim of this project is to predict or recommend career paths based on certain criteria; this requires taking into consideration some factors that could influence individual career decisions, such as:
#
# * Personality traits
# * Interests or hobbies
# * Skills or strengths
# * Educational background
# * Work-life balance preferences
#
# **Data Collection:**
#
# * Conduct a survey to gather my own data.
#
# **Feature Selection:**
#
# * Identify which features (e.g., personality type, education level, interest areas) will be used to train the model.
#
# **Modeling:**
#
# * Classification algorithms to predict the suitable career. For example:Random Forest or Decision Trees might be a good start since they handle categorical data well.
#
# * Logistic Regression or even K-Nearest Neighbors.
#
# * Recommendation systems or clustering techniques.(For a broader range of careers)
#
# **Evaluation:**
#
# * Test model to see how well it predicts a career based on a test set of data. Use metrics like accuracy, precision, and recall.
#
# **Interface/User Interaction:**
#
# * Create a simple web or app interface where users input their details, and the model returns career suggestions.
# * Use Flask (Python) or other frameworks like Streamlit.
#
# **Resources:**
#
# Libraries:
#
# * pandas scikit-learn
# * XGBoost for data processing and modeling.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MultiLabelBinarizer

# Load dataset
df = pd.read_csv('Career Path Survey.csv')

# %%
df.head()
# Out:
#             Timestamp What is your gender?  \
# 0  9/29/2024 12:08:43               Female
# 1  9/29/2024 15:04:09               Female
# 2  9/29/2024 15:16:10               Female
# 3  9/29/2024 16:43:13               Female
# 4  9/29/2024 19:19:23                 Male
#
#   What is your current employment status?  \
# 0            Unemployed, looking for work
# 1                      Employed full-time
# 2            Unemployed, looking for work
# 3                      Employed full-time
# 4                      Employed full-time
#
#   How many years of professional work experience do you have?  \
# 0                                          4-7 years
# 1                                          1-3 years
# 2                                          10+ years
# 3                                          4-7 years
# 4                                          10+ years
#
#   What is your highest level of education? What is your age?  \
# 0              Professional certifications             45-54
# 1                          Master’s degree             25-34
# 2                          Master’s degree             35-44
# 3                        Bachelor’s degree             25-34
# 4                          Master’s degree             45-54
#
#   What is the main reason you are looking to transition into a new career?  \
# 0             Seeking higher income or more security
# 1                                                NaN
# 2             Seeking higher income or more security
# 3                                                NaN
# 4                 Personal growth or a new challenge
#
#                              Other, pls specify  \
# 0                                     The water
# 1                                           NaN
# 2  Financial instability during the transition
# 3                                           NaN
# 4            New challenge and decision making
#
#   What field(s) are you considering for your career transition?  \
# 0                                               Tech
# 1                                                NaN
# 2                                         Academics
# 3                                                NaN
# 4                               Executive Management
#
#   What challenges do you anticipate in making this transition?  ...  \
# 0                   Difficulty finding opportunities            ...
# 1                                                NaN            ...
# 2                   Difficulty finding opportunities            ...
# 3                                                NaN            ...
# 4                   Difficulty finding opportunities            ...
#
#   Do you have any professional certifications or licenses?  \
# 0                                                Yes
# 1                                                 No
# 2                                                NaN
# 3                                                Yes
# 4                                                NaN
#
#   If Yes, please specify            How do you usually spend your free time?  \
# 0                    TRCN         Spending time alone or in quiet reflection
# 1                     NaN       Socializing with friends or attending events
# 2                     NaN                                                NaN
# 3                     Yes  Spending time alone or with one or two close f...
# 4                     NaN                                                NaN
#
#      How do you prefer to recharge after a long day?  \
# 0                                                NaN
# 1         Spending time alone or in quiet reflection
# 2                                                NaN
# 3  Being with people or engaging in social activi...
# 4                                                NaN
#
#   In large social gatherings, do you typically feel  \
# 0        Spending time alone or in quiet reflection
# 1                Energized and excited by the group
# 2                                               NaN
# 3             Overwhelmed and prefer smaller groups
# 4                                               NaN
#
#   How would you describe yourself in conversations?  \
# 0          I mostly listen and speak when necessary
# 1          I mostly listen and speak when necessary
# 2                                               NaN
# 3        I often start conversations and talk a lot
# 4                                               NaN
#
#   Which type of work environment do you prefer?  \
# 0             Flexible, dynamic, and open-ended
# 1             Flexible, dynamic, and open-ended
# 2                                           NaN
# 3        Structured, organized, and predictable
# 4                                           NaN
#
#            Do you prefer working in  \
# 0            Independent, solo work
# 1  Team settings with collaboration
# 2                               NaN
# 3  Team settings with collaboration
# 4                               NaN
#
#   How do you handle uncertainty or change in the workplace?  \
# 0           I adapt quickly and enjoy new challenges
# 1           I adapt quickly and enjoy new challenges
# 2                                                NaN
# 3           I adapt quickly and enjoy new challenges
# 4                                                NaN
#
#      What is your ideal work-life balance?
# 0  Balanced between work and personal time
# 1  Balanced between work and personal time
# 2                                      NaN
# 3  Balanced between work and personal time
# 4                                      NaN
#
# [5 rows x 30 columns]

# %%
# Preprocess dataset
# Drop redundant columns
df.drop(columns=['Timestamp'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 29 columns):
#  #   Column                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                    --------------  -----
#  0   What is your gender?                                                                                                      83 non-null     object
#  1   What is your current employment status?                                                                                   83 non-null     object
#  2   How many years of professional work experience do you have?                                                               65 non-null     object
#  3   What is your highest level of education?                                                                                  83 non-null     object
#  4   What is your age?                                                                                                         83 non-null     object
#  5   What is the main reason you are looking to transition into a new career?                                                  49 non-null     object
#  6   Other, pls specify                                                                                                        9 non-null      object
#  7   What field(s) are you considering for your career transition?                                                             42 non-null     object
#  8   What challenges do you anticipate in making this transition?                                                              47 non-null     object
#  9   Other, please specify                                                                                                     9 non-null      object
#  10  What is your current job title or industry (if applicable)?                                                               63 non-null     object
#  11  How satisfied are you with your current career?
# (On a scale of 1 to 5, where 1 = not satisfied and 5 = highly satisfied)  65 non-null     float64
#  12  What is your primary motivation for changing careers or choosing a career path?                                           65 non-null     object
#  13  Other, please specify .1                                                                                                  11 non-null     object
#  14  What type of career do you aspire to have in the future?                                                                  65 non-null     object
#  15  Which technical skills do you have? (Select all that apply)                                                               75 non-null     object
#  16  Other, pls specify                                                                                                        20 non-null     object
#  17  Which soft skills do you possess? (Select all that apply)                                                                 75 non-null     object
#  18  Other, please specify .2                                                                                                  11 non-null     object
#  19  Do you have any professional certifications or licenses?                                                                  75 non-null     object
#  20  If Yes, please specify                                                                                                    31 non-null     object
#  21  How do you usually spend your free time?                                                                                  65 non-null     object
#  22  How do you prefer to recharge after a long day?                                                                           63 non-null     object
#  23  In large social gatherings, do you typically feel                                                                         65 non-null     object
#  24  How would you describe yourself in conversations?                                                                         65 non-null     object
#  25  Which type of work environment do you prefer?                                                                             65 non-null     object
#  26  Do you prefer working in                                                                                                  65 non-null     object
#  27  How do you handle uncertainty or change in the workplace?                                                                 65 non-null     object
#  28  What is your ideal work-life balance?                                                                                     65 non-null     object
# dtypes: float64(1), object(28)
# memory usage: 18.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Remove whitespaces
df.columns = df.columns.str.strip()

# %%
# Dropping specific columns by name
df.drop(columns=['Other, please specify .1','Other, please specify .2', 'Other, pls specify'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 25 columns):
#  #   Column                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                    --------------  -----
#  0   What is your gender?                                                                                                      83 non-null     object
#  1   What is your current employment status?                                                                                   83 non-null     object
#  2   How many years of professional work experience do you have?                                                               65 non-null     object
#  3   What is your highest level of education?                                                                                  83 non-null     object
#  4   What is your age?                                                                                                         83 non-null     object
#  5   What is the main reason you are looking to transition into a new career?                                                  49 non-null     object
#  6   What field(s) are you considering for your career transition?                                                             42 non-null     object
#  7   What challenges do you anticipate in making this transition?                                                              47 non-null     object
#  8   Other, please specify                                                                                                     9 non-null      object
#  9   What is your current job title or industry (if applicable)?                                                               63 non-null     object
#  10  How satisfied are you with your current career?
# (On a scale of 1 to 5, where 1 = not satisfied and 5 = highly satisfied)  65 non-null     float64
#  11  What is your primary motivation for changing careers or choosing a career path?                                           65 non-null     object
#  12  What type of career do you aspire to have in the future?                                                                  65 non-null     object
#  13  Which technical skills do you have? (Select all that apply)                                                               75 non-null     object
#  14  Which soft skills do you possess? (Select all that apply)                                                                 75 non-null     object
#  15  Do you have any professional certifications or licenses?                                                                  75 non-null     object
#  16  If Yes, please specify                                                                                                    31 non-null     object
#  17  How do you usually spend your free time?                                                                                  65 non-null     object
#  18  How do you prefer to recharge after a long day?                                                                           63 non-null     object
#  19  In large social gatherings, do you typically feel                                                                         65 non-null     object
#  20  How would you describe yourself in conversations?                                                                         65 non-null     object
#  21  Which type of work environment do you prefer?                                                                             65 non-null     object
#  22  Do you prefer working in                                                                                                  65 non-null     object
#  23  How do you handle uncertainty or change in the workplace?                                                                 65 non-null     object
#  24  What is your ideal work-life balance?                                                                                     65 non-null     object
# dtypes: float64(1), object(24)
# memory usage: 16.3+ KB

# %%
#Create new column labels 

# Define a dictionary with old column names as keys and new column names as values
new_column_names = {
    'What is your gender?': 'gender',
    'What is your current employment status?': 'employment_status',
    'How many years of professional work experience do you have?': 'years_experience',
    'What is your highest level of education?': 'education_level',
    'What is your age?': 'age',
    'What is the main reason you are looking to transition into a new career?': 'transition_reason',
    'What field(s) are you considering for your career transition?': 'desired_field',
    'What challenges do you anticipate in making this transition?': 'transition_challenge',
    'Other, please specify': 'challenges_other',
    'What is your current job title or industry (if applicable)?': 'current_job_title',
    'How satisfied are you with your current career?\n(On a scale of 1 to 5, where 1 = not satisfied and 5 = highly satisfied)': 'career_satisfaction',
    'What is your primary motivation for changing careers or choosing a career path?': 'primary_motivation',
    'What type of career do you aspire to have in the future?': 'aspired_job',
    'Which technical skills do you have? (Select all that apply)': 'technical_skills',
    'Other, pls specify ': 'technical_skills_other',
    'Which soft skills do you possess? (Select all that apply)': 'soft_skills',
    'Do you have any professional certifications or licenses?': 'has_certifications',
    'If Yes, please specify': 'certifications',
    'How do you usually spend your free time?': 'free_time_activity',
    'How do you prefer to recharge after a long day?': 'recharge_preference',
    'In large social gatherings, do you typically feel': 'social_gathering_feelings',
    'How would you describe yourself in conversations?': 'conversation_style',
    'Which type of work environment do you prefer?': 'work_environment_preference',
    'Do you prefer working in': 'work_style_preference',
    'How do you handle uncertainty or change in the workplace?': 'uncertainty_handling',
    'What is your ideal work-life balance?': 'ideal_work_life_balance'
}

# Rename the columns
df.rename(columns=new_column_names, inplace=True)

# %%
df.head(1)
# Out:
#    gender             employment_status years_experience  \
# 0       1  Unemployed, looking for work        4-7 years
#
#                education_level  age                       transition_reason  \
# 0  Professional certifications    3  Seeking higher income or more security
#
#   desired_field              transition_challenge challenges_other  \
# 0          Tech  Difficulty finding opportunities        The water
#
#    current_job_title  ...  has_certifications certifications  \
# 0  Transcriptionist   ...                 Yes           TRCN
#
#                            free_time_activity recharge_preference  \
# 0  Spending time alone or in quiet reflection                 NaN
#
#                     social_gathering_feelings  \
# 0  Spending time alone or in quiet reflection
#
#                          conversation_style  \
# 0  I mostly listen and speak when necessary
#
#          work_environment_preference   work_style_preference  \
# 0  Flexible, dynamic, and open-ended  Independent, solo work
#
#                        uncertainty_handling  \
# 0  I adapt quickly and enjoy new challenges
#
#                    ideal_work_life_balance
# 0  Balanced between work and personal time
#
# [1 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# gender                          0
# employment_status               0
# years_experience               18
# education_level                 0
# age                             0
# transition_reason              34
# desired_field                  41
# transition_challenge           36
# challenges_other               74
# current_job_title              20
# career_satisfaction            18
# primary_motivation             18
# aspired_job                    18
# technical_skills                8
# soft_skills                     8
# has_certifications              8
# certifications                 52
# free_time_activity             18
# recharge_preference            20
# social_gathering_feelings      18
# conversation_style             18
# work_environment_preference    18
# work_style_preference          18
# uncertainty_handling           18
# ideal_work_life_balance        18
# dtype: int64

# %%
#Encoding Age
df['age'] = df['age'].map({'45-54':3, '25-34':1, '35-44':2, '18-24':0})

# %%
df['years_experience'].unique()
# Out:
# array(['4-7 years', '1-3 years', '10+ years', nan, '8-10 years',
#        'Less than 1 year'], dtype=object)

# %%
#Encode columns
# Encoding gender
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %%
data.drop(columns=['What is your gender?'], inplace=True)

# %%
# One-hot encoding employment status
data = pd.get_dummies(data, columns=['What is your current employment status?'])

# Normalizing years of professional work experience
scaler = StandardScaler()
data['years_of_experience'] = scaler.fit_transform(data[['How many years of professional work experience do you have?']])

# Encoding highest level of education
data = pd.get_dummies(data, columns=['What is your highest level of education?'])

# Normalizing age
data['age'] = scaler.fit_transform(data[['What is your age?']])

# Handling main reason for transition
data = pd.get_dummies(data, columns=['What is the main reason you are looking to transition into a new career?'])

# Handling fields for career transition
data['career_fields'] = data['What field(s) are you considering for your career transition?'].str.get_dummies(sep=', ')

# Encoding challenges
data = pd.get_dummies(data, columns=['What challenges do you anticipate in making this transition?'])

# Encoding current job title
data['current_job_title'] = data['What is your current job title or industry (if applicable)?'].astype('category').cat.codes

# Normalizing satisfaction rating
data['satisfaction'] = scaler.fit_transform(data[['How satisfied are you with your current career?']])

# Encoding primary motivation
data = pd.get_dummies(data, columns=['What is your primary motivation for changing careers or choosing a career path?'])

# Encoding aspirational job title
data['target'] = data['What type of career do you aspire to have in the future?']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3732\504731554.py in ?()
#       6 data = pd.get_dummies(data, columns=['What is your current employment status?'])
#       7
#       8 # Normalizing years of professional work experience
#       9 scaler = StandardScaler()
# ---> 10 data['years_of_experience'] = scaler.fit_transform(data[['How many years of professional work experience do you have?']])
#      11
#      12 # Encoding highest level of education
#      13 data = pd.get_dummies(data, columns=['What is your highest level of education?'])
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
#    1101             return self.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     741         # Use NumPy API to support order
#     742         if copy is True:
#     743             array = numpy.array(array, order=order, dtype=dtype)
#     744         else:
# --> 745             array = numpy.asarray(array, order=order, dtype=dtype)
#     746
#     747         # At this point array is a NumPy ndarray. We convert it to an array
#     748         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#    2087             and using_copy_on_write()
#
# ValueError: could not convert string to float: '4-7 years'

# %%
# Handling technical skills
mlb = MultiLabelBinarizer()
technical_skills = mlb.fit_transform(data['Which technical skills do you have? (Select all that apply)'].str.split(', '))
data = data.join(pd.DataFrame(technical_skills, columns=mlb.classes_))

# Encoding soft skills
soft_skills = mlb.fit_transform(data['Which soft skills do you possess? (Select all that apply)'].str.split(', '))
data = data.join(pd.DataFrame(soft_skills, columns=mlb.classes_))

# Encoding professional certifications
data['has_certification'] = data['Do you have any professional certifications or licenses?'].apply(lambda x: 1 if x == 'Yes' else 0)

# Handling personality questions (use the earlier mapping logic)
def personality_type(row):
    if row['How do you usually spend your free time?'] == 'Spending time alone or in quiet reflection':
        return 'introvert'
    else:
        return 'extrovert'

data['personality_type'] = data.apply(personality_type, axis=1)

# Final cleanup: Drop unnecessary columns
data.drop(columns=['What is your gender?', 'What is your current employment status?', 'How many years of professional work experience do you have?',
                  'What is your highest level of education?', 'What is your age?', 'What is the main reason you are looking to transition into a new career?',
                  'What field(s) are you considering for your career transition?', 'What challenges do you anticipate in making this transition?',
                  'What is your current job title or industry (if applicable)?', 'What is your primary motivation for changing careers or choosing a career path?',
                  'What type of career do you aspire to have in the future?', 'Which technical skills do you have? (Select all that apply)',
                  'Which soft skills do you possess? (Select all that apply)', 'Do you have any professional certifications or licenses?',
                  'How do you usually spend your free time?', 'How do you prefer to recharge after a long day?',
                  'In large social gatherings, do you typically feel?', 'How would you describe yourself in conversations?',
                  'Which type of work environment do you prefer?', 'Do you prefer working in?',
                  'How do you handle uncertainty or change in the workplace?', 'What is your ideal work-life balance?'], inplace=True)

# Final data preparation
data = data.reset_index(drop=True)
