# %%
import requests

# %%
import requests

# Store API key in a variable
api_key = "CxfesuTgDLduOetp3lNEMI2igVdnAyKW0vLH20N7"

# %%
# APOD get request 
response = requests.get(f"https://api.nasa.gov/planetary/apod?api_key={api_key}")
data = response.json()

# %%
# Display photo in notebook
from IPython.display import Image, display

image_url = data['url']  
display(Image(url=image_url))
# Out:
# <img src="https://apod.nasa.gov/apod/image/2409/Baboon_ZhangYu_960.jpg"/>

# %%
import pandas as pd

df = pd.DataFrame([apod])  
df.head()
# Out:
#                                                links  \
# 0  {'next': 'http://api.nasa.gov/neo/rest/v1/neo/...
#
#                                                 page  \
# 0  {'size': 20, 'total_elements': 36635, 'total_p...
#
#                                   near_earth_objects
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...

# %%
#GET request
response_neo = requests.get(f"https://api.nasa.gov/neo/rest/v1/neo/browse?api_key={api_key}")
asteroid_data = response_neo.json()['near_earth_objects']

# Convert the asteroid data to a DataFrame
asteroid_df = pd.json_normalize(asteroid_data)

# %%
asteroid_df.head()
# Out:
#         id neo_reference_id                    name name_limited designation  \
# 0  2000433          2000433      433 Eros (A898 PA)         Eros         433
# 1  2000719          2000719    719 Albert (A911 TB)       Albert         719
# 2  2000887          2000887    887 Alinda (A918 AA)       Alinda         887
# 3  2001036          2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4  2001221          2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 10.41
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 15.59
# 2  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 13.88
# 3  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                  9.25
# 4  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 17.38
#
#    is_potentially_hazardous_asteroid  \
# ...

# %%
asteroid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   id                                                    20 non-null     object
#  1   neo_reference_id                                      20 non-null     object
#  2   name                                                  20 non-null     object
#  3   name_limited                                          20 non-null     object
#  4   designation                                           20 non-null     object
#  5   nasa_jpl_url                                          20 non-null     object
#  6   absolute_magnitude_h                                  20 non-null     float64
#  7   is_potentially_hazardous_asteroid                     20 non-null     bool
# ...

# %%
# Extracting required columns to new dataframe
new_df = asteroid_df[['id','name_limited','estimated_diameter.kilometers.estimated_diameter_min','absolute_magnitude_h','orbital_data.minimum_orbit_intersection']]

# %%
# Displaying top five rows
new_df.head()
# Out:
#         id name_limited  estimated_diameter.kilometers.estimated_diameter_min  \
# 0  2000433         Eros                                          22.006703
# 1  2000719       Albert                                           2.025606
# 2  2000887       Alinda                                           4.451998
# 3  2001036      Ganymed                                          37.545248
# 4  2001221         Amor                                           0.888290
#
#    absolute_magnitude_h orbital_data.minimum_orbit_intersection
# 0                 10.41                                  .15023
# 1                 15.59                                 .201378
# 2                 13.88                                .0805238
# 3                  9.25                                 .344742
# 4                 17.38                                 .110666

# %%
# Renaming columns
new_df.columns = ['Asteroid_ID',
'Asteroid_name',
'Minimal_estimated_diameter(Km)',
'Absolute_magnitude',
'Relative_velocity(km/s)']

# %%
new_df.head()
# Out:
#   Asteroid_ID Asteroid_name  Minimal_estimated_diameter(Km)  \
# 0     2000433          Eros                       22.006703
# 1     2000719        Albert                        2.025606
# 2     2000887        Alinda                        4.451998
# 3     2001036       Ganymed                       37.545248
# 4     2001221          Amor                        0.888290
#
#    Absolute_magnitude Relative_velocity(km/s)
# 0               10.41                  .15023
# 1               15.59                 .201378
# 2               13.88                .0805238
# 3                9.25                 .344742
# 4               17.38                 .110666

# %%
#Exporting as a CSV file
new_df.to_csv('asteroid_data.csv', index=False)
